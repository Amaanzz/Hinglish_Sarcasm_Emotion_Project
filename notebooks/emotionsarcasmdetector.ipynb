# %% [markdown]
# <a href="https://colab.research.google.com/github/Amaanzz/Hinglish_Sarcasm_Emotion_Project/blob/main/notebooks/emotionsarcasmdetector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets torch scikit-learn emoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 7.5 MB/s eta 0:00:00
# ...

# %%
import transformers, torch, pandas as pd

# %%
print("Setup successful ✅")
# Out:
# Setup successful ✅

# %%
# Download the Hinglish sentiment dataset
# !wget https://raw.githubusercontent.com/singhnivedita/SemEval2020-Task9/master/Fully%20Processed%20Datasets/FinalTrainingOnly.tsv -O train.tsv
# Out:
# --2025-10-24 09:19:15--  https://raw.githubusercontent.com/singhnivedita/SemEval2020-Task9/master/Fully%20Processed%20Datasets/FinalTrainingOnly.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1289876 (1.2M) [text/plain]
# Saving to: ‘train.tsv’
#
# train.tsv           100%[===================>]   1.23M  --.-KB/s    in 0.07s
#
# 2025-10-24 09:19:15 (16.6 MB/s) - ‘train.tsv’ saved [1289876/1289876]

# %%
# Load the dataset with pandas
import pandas as pd

df = pd.read_csv("train.tsv", sep='\t')
print(f"Dataset shape: {df.shape}")
print(f"\nColumn names: {df.columns.tolist()}")
print(f"\nFirst few rows:")
df.head()
# Out:
# Dataset shape: (14593, 3)
#
# Column names: ['3', 'pakistan ka ghra tauq pakistan israel ko tasleem nahein kerta isko palestin kehta - occupi palestin nan', '0']
#
# First few rows:
#     3  \
# 0  41
# 1  48
# 2  64
# 3  66
# 4  68
#
#   pakistan ka ghra tauq pakistan israel ko tasleem nahein kerta isko palestin kehta - occupi palestin nan  \
# 0  madarchod mull ye mathura nahi dikha tha jab m...
# 1  manya pradhan mantri mahoday shriman narendra ...
# 2            krishna jcb full trend chal rahi aa nan
# 3  loksabha janta sirf modi ko vote de rahi thi n...
# 4       bhosdik tum pechvad ki tatti hi rahog bc nan
#
#    0
# 0  0
# 1  2
# 2  2
# 3  2
# 4  0

# %%
# Reload with proper column names
df = pd.read_csv("train.tsv", sep='\t', header=None, names=['id', 'text', 'label'])

print(f"Dataset shape: {df.shape}")
print(f"\nLabel distribution:")
print(df['label'].value_counts())
print(f"\nSample text examples:")
df[['text', 'label']].head(10)
# Out:
# Dataset shape: (14594, 3)
#
# Label distribution:
# label
# 1    5473
# 2    4869
# 0    4252
# Name: count, dtype: int64
#
# Sample text examples:
#                                                 text  label
# 0  pakistan ka ghra tauq pakistan israel ko tasle...      0
# 1  madarchod mull ye mathura nahi dikha tha jab m...      0
# 2  manya pradhan mantri mahoday shriman narendra ...      2
# 3            krishna jcb full trend chal rahi aa nan      2
# 4  loksabha janta sirf modi ko vote de rahi thi n...      2
# 5       bhosdik tum pechvad ki tatti hi rahog bc nan      0
# 6  love u bhaijan ... ♥♥ father + son bharat iamb...      2
# 7  tumhara pass abh deemagh hai nahi islea googl ...      0
# 8              nolo weni anker gae weekend 😂😂😂😂😂 nan      2
# 9  aimim lage raho mullo tumhr issi quran faad gy...      0
